# %% [markdown]
# # Trabalho INF325

# %%
# !wget https://www.w3resource.com/mongodb-exercises/restaurants.zip
# !unzip -o restaurants.zip
# !rm restaurants.zip
# Out:
# --2020-09-11 01:28:31--  https://www.w3resource.com/mongodb-exercises/restaurants.zip
# Resolving www.w3resource.com (www.w3resource.com)... 104.26.14.93, 104.26.15.93, 172.67.69.127, ...
# Connecting to www.w3resource.com (www.w3resource.com)|104.26.14.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262722 (257K) [application/zip]
# Saving to: ‘restaurants.zip’
#
# restaurants.zip     100%[===================>] 256.56K  --.-KB/s    in 0.1s
#
# 2020-09-11 01:28:31 (1.92 MB/s) - ‘restaurants.zip’ saved [262722/262722]
#
# Archive:  restaurants.zip
#   inflating: restaurants.json

# %%
# !mongoimport --db exercicio1 --collection restaurants --drop --file $(pwd)/restaurants.json
# Out:
# 2020-09-11T01:28:53.086+0000	connected to: mongodb://localhost/
# 2020-09-11T01:28:53.090+0000	dropping: exercicio1.restaurants
# 2020-09-11T01:28:54.073+0000	3772 document(s) imported successfully. 0 document(s) failed to import.

# %%
from pymongo import MongoClient
from pprintpp import pprint
import warnings
warnings.filterwarnings('ignore')
mongoclient = MongoClient('localhost', 27017)
db = mongoclient.exercicio1
print(db)
db.restaurants.find({}).count()
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'exercicio1')
# 3772
